# %%
import matplotlib.pyplot as plt
import gymnasium as gym
import gym_cards
from text_wrapper import info_to_text_obs, text_projection

# %%
env_name = 'gym_cards/NumberLine-v0'
env = gym.make(env_name)
obs, info = env.reset()
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(info)
print(text_obs)
# Out:
# {'Target': 5, 'Current': 0}
# Target number: 5. Current number: 0

# %%
"""
Please check the relationship between the symbolic operators
and the numbers here:
https://github.com/RL4VLM/RL4VLM/blob/main/gym-cards/gym_cards/envs/numberline.py#L17

"""
obs, reward, terminated, truncated, info = env.step(1)
plt.imshow(obs)
print(reward, terminated, truncated, info)
# Out:
# 0 False False {'Target': 5, 'Current': 1}

# %%
## Please make sure the string contain the format "action": {act}"
act = text_projection(['"action": "+"'], env_name)
obs, reward, terminated, truncated, info = env.step(act)
plt.imshow(obs)
print(reward, terminated, truncated, info)
# Out:
# 0 False False {'Target': 5, 'Current': 2}

# %%
text_projection(["action: +"], env_name)
# Out:
# 1

# %%
env_name = 'gym_cards/Blackjack-v0'
env = gym.make(env_name)
obs, info = env.reset()
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(info)
print(text_obs)
# Out:
# {'Dealer Card': [(9, '9', 'S'), (10, 'K', 'C')], 'Player Card': [(2, '2', 'C'), (6, '6', 'D')]}
# Dealer's card: 9. Player's cards: 2, 6.

# %%
"""
Please check the relationship between the symbolic operators
and the numbers here:
https://github.com/RL4VLM/RL4VLM/blob/main/gym-cards/gym_cards/envs/blackjack.py#L106

"""
obs, reward, terminated, truncated, info = env.step(1)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0.0 False False {'Dealer Card': [(9, '9', 'S'), (10, 'K', 'C')], 'Player Card': [(2, '2', 'C'), (6, '6', 'D'), (10, 'K', 'H')]}
# Dealer's card: 9. Player's cards: 2, 6, K.

# %%
## Please make sure the string contain the format "actopm: {act}"
act = text_projection(['"action": "hit"'], env_name)
obs, reward, terminated, truncated, info = env.step(act)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0.0 False False {'Dealer Card': [(9, '9', 'S'), (10, 'K', 'C')], 'Player Card': [(2, '2', 'C'), (6, '6', 'D'), (10, 'K', 'H'), (3, '3', 'C')]}
# Dealer's card: 9. Player's cards: 2, 6, K, 3.

# %%
env_name = 'gym_cards/EZPoints-v0'
env = gym.make(env_name)
obs, info = env.reset()
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(info)
print(text_obs)
# Out:
# {'Cards': ['D9', 'C3'], 'Numbers': [9, 3], 'Formula': []}
# Cards: ['D9', 'C3']. Numbers: [9, 3]. Current formula: .

# %%
"""
Please check the relationship between the symbolic operators
and the numbers here:
https://github.com/RL4VLM/RL4VLM/blob/main/gym-cards/gym_cards/envs/ezpoints.py#L26

"""
obs, reward, terminated, truncated, info = env.step(2)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0 False False {'Cards': ['D9', 'C3'], 'Numbers': [9, 3], 'Formula': [3]}
# Cards: ['D9', 'C3']. Numbers: [9, 3]. Current formula: 3.

# %%
## Please make sure the string contain the format "actopm: {act}"
act = text_projection(['"action": "+"'], env_name)
obs, reward, terminated, truncated, info = env.step(act)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0 False False {'Cards': ['D9', 'C3'], 'Numbers': [9, 3], 'Formula': [3, '+']}
# Cards: ['D9', 'C3']. Numbers: [9, 3]. Current formula: 3+.

# %%
env_name = 'gym_cards/Points24-v0'
env = gym.make(env_name)
obs, info = env.reset()
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(info)
print(text_obs)
# Out:
# {'Cards': ['D5', 'H5', 'DJ', 'C9'], 'Numbers': [5, 5, 10, 9], 'Formula': []}
# Cards: ['D5', 'H5', 'DJ', 'C9']. Numbers: [5, 5, 10, 9]. Current formula: .

# %%
"""
Please check the relationship between the symbolic operators
and the numbers here:
https://github.com/RL4VLM/RL4VLM/blob/main/gym-cards/gym_cards/envs/points.py#L27

"""
obs, reward, terminated, truncated, info = env.step(4)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0 False False {'Cards': ['D5', 'H5', 'DJ', 'C9'], 'Numbers': [5, 5, 10, 9], 'Formula': [5]}
# Cards: ['D5', 'H5', 'DJ', 'C9']. Numbers: [5, 5, 10, 9]. Current formula: 5.

# %%
## Please make sure the string contain the format "actopm: {act}"
act = text_projection(['"action": "*"'], env_name)
obs, reward, terminated, truncated, info = env.step(act)
plt.imshow(obs)
text_obs = info_to_text_obs(env_name, info)
print(reward, terminated, truncated, info)
print(text_obs)
# Out:
# 0 False False {'Cards': ['D5', 'H5', 'DJ', 'C9'], 'Numbers': [5, 5, 10, 9], 'Formula': [5, '*']}
# Cards: ['D5', 'H5', 'DJ', 'C9']. Numbers: [5, 5, 10, 9]. Current formula: 5*.
